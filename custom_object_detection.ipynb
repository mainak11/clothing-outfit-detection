# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/My Drive/yolo_custom_train'
# Out:
# backup	     custom_data.zip		    custom_weight
# custom_data  custom_object_detection.ipynb  darknet

# %%
# !unzip '/content/drive/My Drive/yolo_custom_train/custom_data.zip' -d '/content/drive/My Drive/yolo_custom_train/'
# Out:
# Archive:  /content/drive/My Drive/yolo_custom_train/custom_data.zip
#   inflating: /content/drive/My Drive/yolo_custom_train/custom_data/0000dde1f8ec7be1.jpg
#   inflating: /content/drive/My Drive/yolo_custom_train/custom_data/0000dde1f8ec7be1.txt
#   inflating: /content/drive/My Drive/yolo_custom_train/custom_data/0004b19274c21bc7.jpg
#   inflating: /content/drive/My Drive/yolo_custom_train/custom_data/0004b19274c21bc7.txt
#   inflating: /content/drive/My Drive/yolo_custom_train/custom_data/00055f4c50604f37.jpg
#   inflating: /content/drive/My Drive/yolo_custom_train/custom_data/00055f4c50604f37.txt
#   inflating: /content/drive/My Drive/yolo_custom_train/custom_data/00062fd13de3786c.jpg
#   inflating: /content/drive/My Drive/yolo_custom_train/custom_data/00062fd13de3786c.txt
#   inflating: /content/drive/My Drive/yolo_custom_train/custom_data/0007146649b4f758.jpg
#   inflating: /content/drive/My Drive/yolo_custom_train/custom_data/0007146649b4f758.txt
# ...

# %%
# !git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/My Drive/yolo_custom_train/darknet'
# Out:
# Cloning into '/content/drive/My Drive/yolo_custom_train/darknet'...
# remote: Enumerating objects: 15478, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 15478 (delta 9), reused 14 (delta 8), pack-reused 15460
# Receiving objects: 100% (15478/15478), 14.06 MiB | 8.29 MiB/s, done.
# Resolving deltas: 100% (10397/10397), done.
# Checking out files: 100% (2057/2057), done.

# %%
# %cd /content/drive/My Drive/yolo_custom_train/darknet
# Out:
# /content/drive/My Drive/yolo_custom_train/darknet

# %%
# !ls
# Out:
# 3rdparty		darknet_video.py       net_cam_v4.sh
# build			data		       README.md
# build.ps1		image_yolov3.sh        results
# cfg			image_yolov4.sh        scripts
# cmake			include		       src
# CMakeLists.txt		json_mjpeg_streams.sh  vcpkg.json
# DarknetConfig.cmake.in	LICENSE		       video_yolov3.sh
# darknet_images.py	Makefile	       video_yolov4.sh
# darknet.py		net_cam_v3.sh

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ...

# %%
# %cd /content/drive/My Drive/yolo_custom_train
# Out:
# /content/drive/My Drive/yolo_custom_train

# %%
# !python custom_data/creating-files-data-and-name.py

# %%
# !python custom_data/creating-train-and-test-txt-files.py

# %%
# !darknet/darknet detector train custom_data/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/darknet53.conv.74 -dont_show
# Out:
# /bin/bash: darknet/darknet: No such file or directory
